# %% [markdown]
# # Module 7 Assignment

# %% [markdown]
# ## Problem 1
# Create a function called calc_file_length. This function will accept one argument which will be a file path that points to a text file.  The function will first check if the file exists. If the file does not exist, the function will return False. Otherwise, if the file does exist, the function will open the file and count the number of lines in the file. The function will return the number of lines. Please be sure to use variable names that make sense. For example, when you open the file, the variable name you use for the file object should not be ‘filepath’. That is because it is not a file path, it is a file. So, call it something like ‘my_file’.

# %%
import os

# %%
my_filepath = os.path.join(r"C:",'Users','MGaffney','Documents','LOCALAPPS','PYTHON UCI','MODULE 7','username.csv')
file_length = calc_file_length(my_filepath)
print(file_length)
# Out:
# None

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 2
# Define a  function called parse_weather_data_file.  This function will accept one argument which will be a file path that points to a text file. Assume the file has lines of weather data, where the first 8 characters are a weather station identifier. The next three characters are temperature in celsius.

# %%
with open(r'C:\Users\MGaffney\Documents\LOCALAPPS\PYTHON UCI\MODULE 7\weather_data_file.txt', 'r') as myFile:
    count = 0
    for line in myFile:
        count += 1
        lineStripped = line.strip()
        stationID = lineStripped[0:7]
        temperature = lineStripped[8:10]
        humidity = lineStripped[10:12]
        print(stationID, temperature, humidity)
# Out:
# 1234567 -0 17
# 1234567 +3 25
# 1234568 +2 35
# 1234568 +2 25
# 1234568 -1 25
# 1234568 +1 05
# 1234568 +1 44
# 1234568 -0 14
# 1234568 -0 14

# %% [markdown]
# # Dear Professor, I'm sorry that I cannot complete this assignment due to an excruciatingly trying three weeks at work.  My org has announced a restructuring + I'm fighting to save my role.  This was as far as I could get.  Submitting what I could.  Thanks, Monica
